# %% [markdown]
# <a href="https://colab.research.google.com/github/yoonputer/test_deeplearning/blob/master/single_perceptron.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.5.0'

# %%
x_data = [[0,0],[1,0],[0,1],[1,1]]
y_data = [[0],[1],[1],[1]]
type(x_data), type(y_data)
# Out:
# (list, list)

# %%
import numpy as np
x_train = np.array(x_data)
y_train = np.array(y_data)
x_train.shape, y_train.shape
# Out:
# ((4, 2), (4, 1))

# %%
model = tf.keras.models.Sequential()

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.Input(shape=(2,)))
model.add(tf.keras.layers.Dense(1))

model.compile(optimizer='sgd',loss='mse')
# Out:
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.

# %%
model.fit(x_train, y_train)
# Out:
# 1/1 [==============================] - 0s 235ms/step - loss: 0.6447

# %%
model.predict([[0,1]])
# Out:
# array([[-0.47629184]], dtype=float32)

# %% [markdown]
# y = ax + bc + c
#
# y = -1.1581719x + 0.53599274 + 0.02151958

# %%
model.get_weights()
# Out:
# [array([[ 0.92578846],
#         [-0.48704058]], dtype=float32), array([0.01074875], dtype=float32)]

# %%
tf.keras.utils.plot_model(model, show_shapes = True)

# %%
model.fit(x_train, y_train, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6217
# Epoch 2/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6000
# Epoch 3/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5795
# Epoch 4/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5602
# Epoch 5/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5419
# Epoch 6/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.5247
# Epoch 7/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5084
# Epoch 8/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4930
# Epoch 9/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4785
# Epoch 10/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4647
# Epoch 11/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4517
# Epoch 12/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4394
# ...
